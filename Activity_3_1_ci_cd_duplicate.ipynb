# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# upload sample dataset from github
df = pd.read_csv('https://raw.githubusercontent.com/sharmilasandrasagran-67/File-ci-cd/refs/heads/main/data/sample_dataset.csv')
df.head()
# Out:
#    age  sex  chest_pain_type  resting_bp_s  cholesterol  fasting_blood_sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting_ecg  max_heart_rate  exercise_angina  oldpeak  ST_slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df = pd.DataFrame(data)

# Remove duplicates
df_cleaned = df.drop_duplicates()

# %%
# Save processed dataset
df_cleaned.to_csv('https://raw.githubusercontent.com/sharmilasandrasagran-67/File-ci-cd/refs/heads/main/data/processed_dataset.csv', index=False)

print(df_cleaned)
# Out:
#    id   name  age
# 0   1    Ali   22
# 1   2   Siti   23
# 2   3   John   21
# 4   4  Maria   24
# 6   5  Rocky   25
